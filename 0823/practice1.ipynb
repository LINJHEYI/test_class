# %%
x=7
print(x==5)
print(x==7)
print(5<x)
# Out:
# False
# True
# True

# %%
a = 13
if a != 12:
    print('不等於12')
else:
    print('等於12')
# Out:
# 不等於12

# %%
password = input('請輸入密碼')
if password == '1234':
    print('密碼正確!歡迎光臨')
else:
    print('密碼錯誤!')
# Out:
# 請輸入密碼 1234
# 密碼正確!歡迎光臨

# %%
furry = True
small = False
if furry:
    if small:
        print('它是貓')
    else:
        print('它是熊')
else:
    if small:
        print('它是小蜥蜴')
    else:    
        print('它是人類或沒毛的熊')
# Out:
# 它是熊
