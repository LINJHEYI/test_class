# %%
print("Hello world")
# Out:
# Hello world

# %%
print("這是我的第一個函式")
print('這是我的第2個函式')
print(50)
print(50.0)
# Out:
# 這是我的第一個函式
# 這是我的第2個函式
# 50
# 50.0

# %%
print("這是整數", 50)
# Out:
# 這是整數 50

# %%
print(99**99)
# Out:
# 369729637649726772657187905628805440595668764281741102430259972423552570455277523421410650010128232727940978889548326540119429996769494359451621570193644014418071060667659301384999779999159200499899

# %%
print(1.1+2.2)
# Out:
# 3.3000000000000003

# %%
from decimal import Decimal

# 注意：必須傳入字串格式，否則仍會帶入浮點數本身的二進位誤差
result = Decimal('1.1') + Decimal('2.2')
print(result)  # 輸出 3.3
# Out:
# 3.3

# %%
n = int(input("請輸入整數"))
m = float(input("請輸入另一個數值"))
print(n, "*" , m ,"=" , n*m )
# Out:
# 請輸入整數 30
# 請輸入另一個數值 6
# 30 * 6.0 = 180.0

# %%
import math
radius = float(input("請輸入半徑"))
area = radius ** 2 * math.pi
print("半徑:", radius, ", 園面積=", area)
# Out:
# 請輸入半徑 50
# 半徑: 50.0 , 園面積= 7853.981633974483
