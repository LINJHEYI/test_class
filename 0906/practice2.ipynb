# %%
class Person:
    def __init__(self,name:str):
        self.name = name

    def introduce(self):
        print(f"我的名字是{self.name}")

# %%
p1:Person = Person("jenny")
p2:Person = Person(name="robert")

p1.introduce()
p2.introduce()
# Out:
# 我的名字是jenny
# 我的名字是robert
