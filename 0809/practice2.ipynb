# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="海為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 海洋之所以呈現藍色，主要原因並不是因為它反射了藍天，而是因為**海水對陽光的「吸收」與「散射」作用**。
#
# 我們可以把這個原理拆解為以下幾個關鍵原因：
#
# ### 1. 陽光是由「彩虹七色」組成的
# 太陽光看似是白色的，但實際上它包含了紅、橙、黃、綠、藍、靛、紫等各種顏色的光（光譜）。這些光有不同的波長：
# *   **紅光、橙光**：波長較長，能量較低。
# *   **藍光、紫光**：波長較短，能量較高。
#
# ### 2. 海水對紅光的「吸收」
# 當陽光照射到海面並穿透海水時，水分子會與光線發生交互作用：
# *   海水分子非常喜歡吸收**波長較長的光（紅光、橙光、黃光）**。在水深約幾米到幾十米的地方，這些紅光基本上就已經被海水吸收殆盡，轉化為熱能。
# *   相反地，海水對**波長較短的藍光**吸收能力很弱。因此，藍光能夠穿透到更深的水域（甚至可達上百米）。
#
# ### 3. 藍光的「散射」與反射
# 那些沒有被吸收的藍光，在海水中前進時，會不斷碰撞到水分子和其他微小顆粒。這時會發生「散射」（光線向四面八方折射）與反射。
# 其中，一部分被散射的藍光會折射回我們的眼睛裡。因為我們眼睛接收到了這些被散射出來的藍光，所以海看起來就是藍色的。
#
# ---
#
# ### 常見的迷思：是因為反射天空的顏色嗎？
# **這只是部分原因。**
# 雖然在晴天時，海面確實會像鏡子一樣反射天空的藍色，讓海看起來更藍；但在陰天時，深海依然是藍色的。如果你裝一桶海水起來，它看起來是透明無色的，這是因為水量太少，吸收和散射的效果不明顯，必須要有足夠深、足夠多的水，藍色才會顯現出來。
#
# ### 為什麼有些海看起來是綠色、黃色或黑色？
# 海水的顏色也會受到水中的雜質影響：
# *   **綠色的海**：如果海水中有大量的綠色浮游植物（藻類），它們含有的葉綠素會吸收藍光並反射綠光，海就會呈現綠色（通常出現在營養豐富的近海）。
# *   **黃褐色或混濁的海**：如果靠近河口，河水帶來大量的泥沙、有機物，就會讓海水看起來呈黃色或褐色。
# *   **深藍甚至黑色（黑潮）**：如果海水非常乾淨，幾乎沒有雜質和浮游生物，光線會穿透得極深，幾乎沒有光線反射回來，海看起來就會是極深邃的墨藍色或黑色。
