# %%
from google import genai

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="海為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 海洋之所以呈現藍色，主要是因為**陽光與海水之間的物理作用**（吸收與散射）。這可以拆解為以下幾個核心原因：
#
# ### 1. 陽光其實是「彩虹色」的
# 太陽光看似是白色的，但它其實是由紅、橙、黃、綠、藍、靛、紫等不同顏色的光（光譜）混合而成的。這些光有不同的**波長**：
# *   **紅光、橙光**：波長較長，能量較低。
# *   **藍光、紫光**：波長較短，能量較高。
#
# ### 2. 海水的「選擇性吸收」
# 當陽光照射到海面並穿透海水時，水分子會開始吸收光線：
# *   **紅光、橙光、黃光**等長波長的光，非常容易被水分子吸收。在水深約 10 公尺以內，紅光幾乎就已經被吸收光了。
# *   **藍光**因為波長短、能量高，不容易被水分子吸收，能夠穿透到更深的水域。
#
# ### 3. 藍光的「散射」
# 既然藍光沒有被吸收，那它去哪裡了呢？
# 藍光在穿透海水時，會與水分子以及海水中的微小顆粒碰撞，並向四面八方**散射**（Bounce around）。一部分被散射的藍光會折射回我們的眼睛裡。因此，我們看著大海時，接收到的主要是被折射出來的藍光，海水看起來就是藍色的。
#
# ---
#
# ### 💡 常見的迷思與補充
#
# *   **迷思：海是藍的，是因為反射了藍色的天空？**
#     *   **答案：這只是部分原因。** 天空的確會反射在海面上（這就是為什麼陰天時海看起來灰灰的），但即使在室內裝滿極深的水池，水依然會呈現藍色。海水的藍，本質上還是因為海水自身的「吸收與散射」作用。
#
# *   **為什麼杯子裡的水是透明的？**
#     *   因為杯子裡的水太少了。光線在穿過這麼短的距離時，幾乎沒有被吸收和散射，所以看起來是透明的。必須要累積到一定深度的水，藍色才會顯現出來。
#
# *   **為什麼有些海是綠色、黃色或黑色的？**
#     *   **綠色**：如果海水中有豐富的浮游植物（含有葉綠素），葉綠素會吸收藍光並反射綠光，海就會呈現綠色。
#     *   **黃褐色**：靠近陸地的海域，如果含有大量河流沖刷下來的泥沙或有機物，海就會顯得混濁呈黃褐色。
#     *   **深藍到黑色**：當水深非常深（超過 200 公尺以上），所有的光線都被吸收殆盡，深海就會變成一片漆黑。
