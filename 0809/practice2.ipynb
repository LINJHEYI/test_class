# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="海為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 海水之所以呈現藍色，並不是因為海水本身是藍色的（盛在杯子裡的純淨海水是無色的），而是因為**陽光與水分子之間的相互作用（吸收與散射）**。
#
# 這主要可以歸納為以下三個原因：
#
# ### 1. 水對光線的「選擇性吸收」
# 太陽光看似是白色的，但其實是由紅、橙、黃、綠、藍、靛、紫等七彩光譜組成的。這些光線的波長不同：
# *   **紅光、橙光、黃光**：波長較長，能量較低，極易被水分子吸收。當陽光射入海中，這些暖色光在幾米到幾十米深的地方就陸續被海水吸收並轉化為熱能。
# *   **藍光、紫光**：波長較短，能量較高，不容易被水分子吸收，能夠穿透到更深的海水裡。
#
# ### 2. 藍光的「散射」
# 當不容易被吸收的藍色光線穿透海水時，它們會碰撞到水分子或其他微小顆粒。由於藍光的波長短，它很容易往四面八方「散射」（瑞利散射，Rayleigh scattering）。
# 這些被散射的藍光有一部分會折射出水面，進到我們的眼睛裡，所以我們看到的海水就是藍色的。
#
# *(註：那為什麼不是紫色的？雖然紫光的波長比藍光更短、更容易散射，但一來太陽光中的紫光本來就比藍光少，二來人類的眼睛對藍光比對紫光更敏感，所以我們看到的主要是藍色。)*
#
# ### 3. 天空的反射（次要原因）
# 晴天時，海洋表面像一面巨大的鏡子，會反射天空的藍色，這會讓海水看起來更藍。但即使在陰天，深海的水依然是藍綠色的，這證明了「吸收與散射」才是最主要的原因。
#
# ---
#
# ### 補充：為什麼有的海是綠色、黃色或黑色的？
#
# 並非所有的海都是藍色的，這取決於海水中的「雜質」：
# *   **綠色的海**：如果海水裡有大量的**浮游植物（藻類）**，它們含有葉綠素，會吸收藍光並反射綠光，海水就會呈現綠色或青綠色。
# *   **黃褐色／混濁的海**：如果靠近河口，海水裡有大量的泥沙、有機碎屑，就會呈現黃色或褐色（例如黃海）。
# *   **深藍色到近乎黑色**：在極深的海域（如馬里亞納海溝），光線完全無法到達，海水看起來就是一片黑暗。
